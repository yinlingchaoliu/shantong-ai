# %% [markdown]
# # 卷积神经网络
# * 图像识别
# * 分类与检索
# * 特征提取
# * 超分辨率重构
# * 医学任务
# * OCR
# * 无人驾驶
# * 人脸识别(关键点提取，特征提前)
#
# ![image.png](attachment:b534c525-787e-4d26-9fbe-735209fe22dd.png)
# nn 二维
# cnn 三维 h*w*c(特征)
# ![image.png](attachment:c12b9a15-7733-487a-bdd2-7c8efb22dc25.png)
# 输入层
# 卷积：提取特征
# 池化：压缩特征
# 全连接层
# 输出层
#
# # 卷积层
# ![image.png](attachment:d47dc167-767e-42f4-aba2-319d0d07c333.png)
# [3,3,2]    [0,1,2]
# [0,0,1]  * [2,2,0] = x1 * w1  特征图
# [3,1,3]    [0,1,2]
