# %% [markdown]
# # torchvision
# * datasets
# * models (vgg resnet)
# * transform
# * 权重 偏置参数 用别人模型 帮助快速收敛
# * 迁移学习
#
# # 数据处理部分
# * 数据增强
# * 数据预处理
# * DataLoader
#
# # 网络模块设置
# * 加载预训练模型，用别人的权重和参数继续训练 迁移学习
# * 微调 (改最后全连接层)
# * 全部训练，或 只训练最后任务层
#
# # 网络模型保存和测试
# * 有选择性保存
# * 读取模型进行实际测试
#
# ![image.png](attachment:72de016b-b559-4133-b098-2a41b79d49dd.png)
# ![image.png](attachment:4dd81efc-f289-4690-9252-79cc07931a07.png)
# 迁移学习 : 借用别人模型(权重和参数) 训练自己的模型
# 卷积层是特征提取，全连接层是定向输出的，一般改全连接层，输入参数适配，复用模型框架的权重和参数
# ![image.png](attachment:2e004382-ed00-4b65-a61b-9bf883bc5421.png)

# %%
import torchvision.models as models
resnet18 = models.resnet18()
